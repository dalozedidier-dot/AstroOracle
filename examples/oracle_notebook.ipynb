# %% [markdown]
# # AstroOracle notebook UI
# Click-based annotation with ipywidgets + Plotly.

# %%
from astrooracle.annotations import append_annotations
from astrooracle.config import OracleConfig
from astrooracle.core import fetch_cutouts, load_candidates, select_candidates
from astrooracle.ui_notebook import OracleUI
from astrooracle.viz_plotly import render_cutouts_plotly

cfg = OracleConfig.default()
ui = OracleUI(
    cfg,
    load_candidates,
    select_candidates,
    fetch_cutouts,
    render_cutouts_plotly,
    append_annotations,
)
